# %%
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile
from pygame import mixer
import numpy as np

file = 'could-heaven.wav'

fs_rate, data = wavfile.read(file)
assert isinstance(data, np.ndarray) and len(data.shape) == 2 and data.shape[1] == 2


channel = data[:, 0]
assert channel.min() == -32768 and channel.max() == 32767
# normed = (channel / (2 ** 15)) * 2 - 1
# print(normed.min(), normed.max())
freqs = fft(channel)
# mixer.init()
# mixer.music.load(file)
# mixer.music.play()

# import time
# while mixer.music.get_busy():
#     time.sleep(0.1)

# %%
fs
# Out:
# 44100

# %%
plt.plot(freqs)
# Out:
# /home/pawel/music-test/.venv/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
